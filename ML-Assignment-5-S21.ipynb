# %% [markdown]
# # CMSC478 Machine Learning - Spring 2021
#
# ## Instructor: Fereydoon Vafaei
#
# ## Assignment-5: Image Classification with Convolutional Neural Networks

# %% [markdown]
# *Type your name and ID here*

# %% [markdown]
# ## Overview and Learning Objectives

# %% [markdown]
# In Assignment-5, you're going to perform image classification using Convolutional Neural Networks in Tensorflow and Keras.
#
# Pedagogically, this assignment will help you:
# - better understand how CNNs are built and applied on ML/CV tasks specifically for image classification.
# - practice CNN implementation using Tensorflow 2 and Keras.
# - practice Transfer Learning using pretrained models.

# %% [markdown]
# **NO LATE PERIOD:** Assignment-5 has NO late period, i.e. late submissions will NOT be accepted. Read the instructions and grading rubric carefully. Building and training CNNs are time-consuming tasks. **You're strongly recommended to get started on A5 as soon as possible!**

# %% [markdown]
# **Training Requirement**: Submissions with no training and history plots will get ZERO, NO EXCEPTION! CNN architectures and tf/keras codes will get no points if you do not actually train and test them and plot their train history. **Your submitted notebook should clearly include ALL the training logs as well as the history plots; otherwise you get zero for A5.**

# %% [markdown]
# <b>Course Policy Reminder</b>
# Debugging the codes and error resolution are always the students' responsbility. This policy will be enforced in email communications and the office hours. Keep in mind that all assignments are individual graded tasks. Any collaboration with other students is strictly prohibited and is considered as cheating. Students should NOT share any answer, solution, or code with other students. Violations of these policies would be penalized according to UMBC academic integrity policy.

# %% [markdown]
# Follow the instructions for each step very carefully.
#
# Wherever needed, you should replace `...` elipsis with your code.

# %% [markdown]
# ### Import Cell

# %% [markdown]
# All imports should be included in this import cell.

# %%
''' Import Cell
    Import necessary Python/Sklearn modules as well as Tensorflow/Keras '''

...

# %%
print("tf Version: ", tf.__version__)
# Out:
# tf Version:  2.4.1

# %% [markdown]
# ## Part-I [20 Points] - CIFAR-10 Baseline Model

# %% [markdown]
# You're going to build a CNN image classifier for [CIFAR-10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset. Since it's one of the built-in datasets in keras, it will be downloaded and loaded automatically using the following provided code.

# %%
# Load CIFAR10 data 
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# > The CIFAR10 dataset contains 60,000 color images in 10 classes, with 6,000 images in each class. The dataset is divided into 50,000 training images and 10,000 testing images. The classes are mutually exclusive and there is no overlap between them.

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# To help you focus on training CNNs, the preprocessing steps are provided.

# %%
# Normalize pixel values to be between 0 and 1
X_train, X_test = X_train / 255.0, X_test / 255.0

# %% [markdown]
# > You should one-hot encode the image classes/labels using [`to_categorical()` method](https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical).

# %%
# one hot encode target values/labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# > Notice how label vetor shapes changed after one-hot encoding.

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (50000, 10)
# (10000, 10)

# %% [markdown]
# > You can visualize some sample images.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

# %% [markdown]
# ### Building the Baseline CNN for Image Classification of CIFAR-10

# %% [markdown]
# Using the CNN model in the [Tensorflow Tutorial](https://www.tensorflow.org/tutorials/images/cnn), build a `baseline_model` that can achieve a minimum required test accuracy of 0.70 (evaluated on the test set).
#
# To build the `baseline_model`, you may or may not make changes to the model that you see in the tutorial, but the `baseline_model` would use a common pattern: a stack of [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) and [MaxPooling2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D) layers.
#
# **Test Accuracy Requirement:** The `baseline_model` must achieve at least 0.70 accuracy on CIFAR-10 test images.

# %%
''' baseline_model based on: https://www.tensorflow.org/tutorials/images/cnn '''

baseline_model = ...

# %% [markdown]
# **Hints**:
#
# > You may make changes to the model that you see in the tutorial. Notice how the output shape changes after each layer in the tutorial model and the `baseline_model` summary below.
#
# > Your `baseline_model` does NOT have to macth with the summary below as long as it satisfies the minimum test accuracy requirement of 0.70.
#
# > Note that since you are working with image data, you should use a `Flatten()` layer BEFORE the `Dense` layers as you can see in the tutorial model and the summary below.
#
# > Also note that the output layer specifications (number of neurons and activation function) are determined by the ML task, i.e. 10-class classification.

# %%
baseline_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                102464
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 159,434
# Trainable params: 159,434
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > Be careful to use the correct loss function and metric for classification task with one-hot encoded labels when you compile the model.

# %%
''' compile baseline_model with optimizer and learning rate of your choice (you may tune them)
    be careful about the loss and metric'''

...

# %% [markdown]
# > Train the `baseline_model` with 10 epochs only, and then plot the train history.

# %%
''' train the baseline_model on X_train, y_train with 10 epochs
    validation_data is X_test, y_test or you can specify validation_split '''

history_baseline = ...
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 5s 2ms/step - loss: 1.7210 - accuracy: 0.3671 - val_loss: 1.1949 - val_accuracy: 0.5726
# Epoch 2/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.1419 - accuracy: 0.5959 - val_loss: 1.0505 - val_accuracy: 0.6260
# Epoch 3/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.9676 - accuracy: 0.6618 - val_loss: 1.0542 - val_accuracy: 0.6336
# Epoch 4/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.8493 - accuracy: 0.7036 - val_loss: 0.8914 - val_accuracy: 0.6929
# Epoch 5/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.7724 - accuracy: 0.7287 - val_loss: 0.8339 - val_accuracy: 0.7138
# Epoch 6/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.7007 - accuracy: 0.7531 - val_loss: 0.8984 - val_accuracy: 0.6939
# Epoch 7/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.6515 - accuracy: 0.7696 - val_loss: 0.8358 - val_accuracy: 0.7120
# Epoch 8/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.6033 - accuracy: 0.7885 - val_loss: 0.8455 - val_accuracy: 0.7096
# Epoch 9/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.5587 - accuracy: 0.8013 - val_loss: 0.8572 - val_accuracy: 0.7175
# Epoch 10/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.5152 - accuracy: 0.8209 - val_loss: 0.8377 - val_accuracy: 0.7303

# %%
''' plot the history with figsize=(10,5)
    the plot should display the grid and the whole range of values for epoch and accuracy
    the plot should have axis labels and legend location should be lower right '''

...

# %% [markdown]
# > The training plot clearly shows a gap between the train accuracy and validation accuracy which is an indication of **overfitting**.
#
# > Now, evaluate the baseline model on test images.
#
# > **Test Accuracy Requirement:** The `baseline_model` must achieve at least 0.70 test accuracy on CIFAR-10 test images.
#
# > Since you used test set `X_test` and `y_test` as the validation set, the results of running `evaluate()` method on `(X_test, y_test)` should match with the validation accuracy that you observed after the last epoch of training.

# %%
# Evaluate the baseline_model on the test set
baseline_test_loss, baseline_test_acc = ...
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.8377 - accuracy: 0.7303

# %%
round(baseline_test_acc, 2)
# Out:
# 0.73

# %% [markdown]
# ## Part-II [40 Points] Transfer Learning with Pretrained Keras Models

# %% [markdown]
# In Part-II, you're going to perform **Transfer Learning** using CNN architectures in [Keras Applications](https://keras.io/api/applications/) pretrained on [ImageNet](https://www.image-net.org/) dataset.
#
# As discussed in DNN and CNN lectures, by **Transfer Learning** you can use the lower layers of the models that are already pretrained on some famous datasets like [ImageNet](https://www.image-net.org/) dataset. For this problem, you're going to use a CNN architecture that you choose from the set of pretrained models in Keras such as `DenseNet121` or `ResNet50`. You can use any of the models listed in [Keras Applications](https://keras.io/api/applications/) although some models like `InceptionV3` may have image size limitations that do not fit with this dataset.
#
# Read the slides and the textbook examples as well as [Keras Documentation Usage Examples](https://keras.io/api/applications/#usage-examples-for-image-classification-models) to learn how to use CNNs pretrained on `'imagenet'`.

# %% [markdown]
# > **Note**: Read the documentations and the code examples very carefully.
#
# > **Test Accuracy Requirement:** The `transfer_model` must achieve at least 0.65 test accuracy on CIFAR-10 test images.
#
# > The goal of Part-II is helping students learn how to do trannsfer learning in practice, so don't worry that 0.65 is less than the `baseline_model` test accuracy 0.70. In fact, transfer learning is quite effective but would require more tuning and experiments, and you may choose to improve your transfer learning model to satisfy the requirements of your `final_model` in Part-III.
#
# > The first step in transfer learning is getting the lower layers of one of the pretrained models from `keras.applications`. You should set the `weights='imagenet'` and `include_top=False` to use lower layers only. You should also use `'max'` pooling. Be careful to set the `input_shape` correctly.

# %%
transfer = keras.applications. ...

# %%
net = transfer.output

# %% [markdown]
# > Now add the top layers, i.e. `Flatten` and `Dense` layers including the output layer. Be very careful about the specifications of the output layer.
#
# > Note that in this step you add layers using functional API. See, for instance, how `(net)` comes after `Flatten()` and `Dense()` in each step.

# %%
''' add the top layers, i.e. Flatten and Dense layers including the output layer '''
net = layers.Flatten()(net)
net = layers.Dense(...)(net) # Dense Layer
net = ...
# Add as many Dense layers as needed
...
output = ... # Output layer for 10-class classification

# %%
''' Build transfer_model
    see the examples and determine how you should pass the arguments of the Model(...) '''

transfer_model = Model(...)

# %%
# Make the transfer layers non-trainable
...

# %%
''' compile transfer_model with optimizer and learning rate of your choice (you may tune them) '''

...

# %% [markdown]
# > **Note**: Training `DenseNet121` or `ResNet50` and other pretrained models may take a long time as they are more complex than the `baseline_model` with lots of parameters, although the fact that you've made the transfer layers' parameters non-trainable would help with reducing the training time to some degree.

# %%
''' train transfer_model on X_train, y_train with at least 20 epochs 
    you may train with more epochs if needed '''

history_transfer = ...
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 23s 12ms/step - loss: 1.8084 - accuracy: 0.3890 - val_loss: 1.1462 - val_accuracy: 0.6012
# Epoch 2/30
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.2661 - accuracy: 0.5621 - val_loss: 1.0929 - val_accuracy: 0.6223
# Epoch 3/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1976 - accuracy: 0.5855 - val_loss: 1.0880 - val_accuracy: 0.6222
# Epoch 4/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1631 - accuracy: 0.5999 - val_loss: 1.0612 - val_accuracy: 0.6295
# Epoch 5/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1358 - accuracy: 0.6095 - val_loss: 1.0397 - val_accuracy: 0.6420
# Epoch 6/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1167 - accuracy: 0.6158 - val_loss: 1.0350 - val_accuracy: 0.6435
# Epoch 7/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0925 - accuracy: 0.6250 - val_loss: 1.0234 - val_accuracy: 0.6464
# Epoch 8/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0723 - accuracy: 0.6314 - val_loss: 1.0179 - val_accuracy: 0.6434
# Epoch 9/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0652 - accuracy: 0.6379 - val_loss: 1.0198 - val_accuracy: 0.6471
# Epoch 10/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0536 - accuracy: 0.6371 - val_loss: 1.0050 - val_accuracy: 0.6505
# Epoch 11/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0430 - accuracy: 0.6429 - val_loss: 1.0019 - val_accuracy: 0.6510
# Epoch 12/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0226 - accuracy: 0.6519 - val_loss: 0.9981 - val_accuracy: 0.6549
# Epoch 13/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0148 - accuracy: 0.6503 - val_loss: 0.9970 - val_accuracy: 0.6519
# Epoch 14/30
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.0041 - accuracy: 0.6591 - val_loss: 0.9974 - val_accuracy: 0.6548
# Epoch 15/30
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.9892 - accuracy: 0.6594 - val_loss: 0.9952 - val_accuracy: 0.6556
# Epoch 16/30
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.9876 - accuracy: 0.6637 - val_loss: 0.9926 - val_accuracy: 0.6543
# Epoch 17/30
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.9804 - accuracy: 0.6654 - val_loss: 0.9885 - val_accuracy: 0.6558
# Epoch 18/30
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.9791 - accuracy: 0.6645 - val_loss: 0.9809 - val_accuracy: 0.6614
# Epoch 19/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9526 - accuracy: 0.6748 - val_loss: 0.9880 - val_accuracy: 0.6570
# Epoch 20/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9548 - accuracy: 0.6723 - val_loss: 0.9779 - val_accuracy: 0.6690
# Epoch 21/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9499 - accuracy: 0.6762 - val_loss: 0.9828 - val_accuracy: 0.6589
# Epoch 22/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9523 - accuracy: 0.6727 - val_loss: 0.9908 - val_accuracy: 0.6610
# Epoch 23/30
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.9401 - accuracy: 0.6770 - val_loss: 0.9900 - val_accuracy: 0.6584
# Epoch 24/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9451 - accuracy: 0.6782 - val_loss: 0.9821 - val_accuracy: 0.6650
# Epoch 25/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9300 - accuracy: 0.6810 - val_loss: 0.9928 - val_accuracy: 0.6582
# Epoch 26/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9281 - accuracy: 0.6817 - val_loss: 0.9924 - val_accuracy: 0.6595
# Epoch 27/30
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.9276 - accuracy: 0.6840 - val_loss: 0.9969 - val_accuracy: 0.6596
# Epoch 28/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9219 - accuracy: 0.6856 - val_loss: 0.9826 - val_accuracy: 0.6636
# Epoch 29/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9110 - accuracy: 0.6877 - val_loss: 0.9869 - val_accuracy: 0.6649
# Epoch 30/30
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9074 - accuracy: 0.6888 - val_loss: 0.9829 - val_accuracy: 0.6626

# %%
''' plot the history with figsize=(10,5)
    the plot should display the grid and the whole range of values for loss and accuracy
    the plot should have axis labels and legend location should be lower right '''

...

# %% [markdown]
# > **Test Accuracy Requirement:** The `transfer_model` must achieve at least 0.65 test accuracy on CIFAR-10 test images.

# %%
# Evaluate the transfer_model on the test set
transfer_test_loss, transfer_test_acc = ...
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.9829 - accuracy: 0.6626

# %%
round(transfer_test_acc, 2)
# Out:
# 0.66

# %% [markdown]
# ## Part-III [40 Points] - Final Model

# %% [markdown]
# In Part-III, you're going to improve the CNN models that you built in Part-I and Part-II to achieve the minimum required test accuracy of 0.80 and higher as evaluated on the test set. Your grade for Part-III is proportinate to your test accuracy, the higher your accuracy, the higher your grade.
#
# - **Training Requirement:** You must train all of your models and generate the history plots. Use "Save and Checkpoint" at the top menu of the Jupyter Notebook to save your outputs and plots before submission because if your submitted notebook does not show the training and the histroty plots, you get zero for this assignment.
#
#
# - **Test Accuracy Requirement**: For your final model, the minimum required test accuracy on the test images of CIFAR-10 is 0.80. Anything below 0.80 will get zero for Part-III. For 0.80+ accuracies, your grade for Part-III is calculated as follows:
#
# - Part-III grade:
#     * Test accuracy of the final model < 0.80 --> Part-III grade: zero
#     * 0.80 <= Test accuracy < 0.85 --> Part-III grade: 30 points
#     * 0.85 <= Test accuracy --> Part-III grade: 40 points
#
# > For example, if your test accuracy (evaluated on the test set) is 0.81, your Part-III grade will be 30. If you get a test accuracy of 0.85 and above, you get the full 40 points for Part-III.
#
# - See "Grading" for further information on how A5 is graded.

# %% [markdown]
# ### Tips for Improving CNN Using Regularization, Data Augmentation and Other Techniques

# %% [markdown]
# For the final CNN model, you may use and improve either the `baseline_model` or `transfer_model`, or any other model that you think may work better. You may search for external solutions but you must cite them properly (see **References** section for instructions on proper citation).
#
# Some techniques that might be helpful to improve the baseline model is listed below, but you can try any other technique that you think might be helpful to improve your model.
#
# - Regularization using [Dropout](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout)
#
# - Initialization Methods such as He
#
# - [Batch Normalization](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization)
#
# - Data Augmentation using [Tensorflow ImageDataGenerator](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator) --- There are some code examples for Data Augmentation in CNN slides.
#
# - Learning Rate Scheduling
#
# - Any other techniques and implementations of your choice
#
# You may also search for solutions online and borrow them with proper citation. See "References" for further information on how to properly cite any resource you may use.
#
# You certainly need to fine-tune your model, but some helpful strategies to start with are as follows:
#
#
# - You may need to add more Conv2D and MaxPooling2D layers, but don't add too many layers initially, increase your model complexity gradually.
#
#
# - Start with short training sessions with 20-50 epochs until you see some progress. Once you hit 0.80 accuracy and secured your 30 score for Part-III, you may run for longer training sessions to increase your score. To get 0.80+, you may need to run training for at least 100 epochs or use callback and early stopping to determine optimal number of epochs. For higher accuracies, you may need to run training up to ~400-500 epochs with no intervention, but keep in mind that it may take a long time, so it would be rational to first aim for the minimum required test accuracy of 0.80 with fewer number of epochs like 20 to 50 and then increase accordingly.
#
#
# - You may initially use a learning rate of 0.001 and Adam, RMSProp or SGD as the optimizer. You may want to tune the learning rate and/or try learning rate scheduling methods.
#
#
# - Check the progress in the training log of the baseline model and see how the accuracy improves. Similarly, you should watch the progress of your CNN during training, and if you don't see any progress in reducing loss and increasing accuracy, stop training and make any necessary changes. Don't wait for too long if you don't see any progress at all in the first epochs because that's a red flag that something is not right in your model, and you should fix any possible problem first. It's fine though if the improvements in each epoch are small, that's how CNNs learn!

# %%
''' Build a CNN using Conv2D and MaxPooling2D,
    as well as any other regularization technique such as Dropout, Batch Normalization, Data Augmentation,
    or any other technique you learned or are interested to try in training DNNs and CNNs.
    
    You may use Transfer Learning and/or you may use models that you find in external resources.

    NOTE: If you borrow code from any extrenal resource, 
    you must document your code by understandable and easy-to-follow comments for each cell/block. '''

final_model = ...

# %%
# Compile your final_model
...

# %%
''' use Data Augmentation if needed --- you may see examples in CNN slides/textbook
    to use data augmentation, you should use ImageDataGenerator()
    
    note that if you use data augmentation, you would then need to use .fit_generator() method for training '''

# datagen = ImageDataGenerator(...) # complete this cell only if you want to use data augmentation
# You should also use flow and steps properly
...

# %% [markdown]
# > **Training Requirement**: Submissions with no training and history plots will get ZERO, NO EXCEPTION! CNN architectures and tf/keras codes will get no points if you do not actually train and test them and plot their train history. **Your submitted notebook should clearly include ALL the training logs as well as the history plots; otherwise you get zero for A5.**

# %%
# Train your final_model
history_final = ...
# Out:
# Epoch 1/200
# 781/781 [==============================] - 15s 19ms/step - loss: 2.5330 - accuracy: 0.2390 - val_loss: 1.5167 - val_accuracy: 0.4461
# Epoch 2/200
# 781/781 [==============================] - 14s 19ms/step - loss: 1.6538 - accuracy: 0.3971 - val_loss: 1.4421 - val_accuracy: 0.4742
# Epoch 3/200
# 781/781 [==============================] - 14s 19ms/step - loss: 1.5007 - accuracy: 0.4548 - val_loss: 1.5017 - val_accuracy: 0.4507
# Epoch 4/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.4056 - accuracy: 0.4869 - val_loss: 1.3718 - val_accuracy: 0.4947
# Epoch 5/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.3498 - accuracy: 0.5112 - val_loss: 1.2659 - val_accuracy: 0.5477
# Epoch 6/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.2890 - accuracy: 0.5361 - val_loss: 1.5936 - val_accuracy: 0.4434
# Epoch 7/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.2299 - accuracy: 0.5571 - val_loss: 1.2643 - val_accuracy: 0.5316
# Epoch 8/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.1971 - accuracy: 0.5692 - val_loss: 1.3809 - val_accuracy: 0.5079
# Epoch 9/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.1564 - accuracy: 0.5818 - val_loss: 1.1658 - val_accuracy: 0.5777
# Epoch 10/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.1248 - accuracy: 0.5970 - val_loss: 1.0758 - val_accuracy: 0.6189
# Epoch 11/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.0926 - accuracy: 0.6104 - val_loss: 1.1703 - val_accuracy: 0.5823
# Epoch 12/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.0772 - accuracy: 0.6184 - val_loss: 1.1789 - val_accuracy: 0.5793
# Epoch 13/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.0475 - accuracy: 0.6269 - val_loss: 1.2115 - val_accuracy: 0.5742
# Epoch 14/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.0310 - accuracy: 0.6313 - val_loss: 1.0506 - val_accuracy: 0.6259
# Epoch 15/200
# 781/781 [==============================] - 15s 19ms/step - loss: 1.0065 - accuracy: 0.6392 - val_loss: 1.0161 - val_accuracy: 0.6346
# Epoch 16/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.9868 - accuracy: 0.6490 - val_loss: 0.9453 - val_accuracy: 0.6628
# Epoch 17/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.9701 - accuracy: 0.6540 - val_loss: 0.9815 - val_accuracy: 0.6495
# Epoch 18/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.9450 - accuracy: 0.6667 - val_loss: 0.9145 - val_accuracy: 0.6728
# Epoch 19/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.9261 - accuracy: 0.6711 - val_loss: 0.9261 - val_accuracy: 0.6721
# Epoch 20/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.9229 - accuracy: 0.6750 - val_loss: 0.8982 - val_accuracy: 0.6764
# Epoch 21/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.9163 - accuracy: 0.6755 - val_loss: 0.9037 - val_accuracy: 0.6791
# Epoch 22/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8952 - accuracy: 0.6863 - val_loss: 0.8620 - val_accuracy: 0.6888
# Epoch 23/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8926 - accuracy: 0.6844 - val_loss: 0.8451 - val_accuracy: 0.6994
# Epoch 24/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8865 - accuracy: 0.6889 - val_loss: 0.8887 - val_accuracy: 0.6883
# Epoch 25/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8821 - accuracy: 0.6893 - val_loss: 0.9326 - val_accuracy: 0.6753
# Epoch 26/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8439 - accuracy: 0.7042 - val_loss: 0.8985 - val_accuracy: 0.6840
# Epoch 27/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8388 - accuracy: 0.7081 - val_loss: 0.8415 - val_accuracy: 0.6994
# Epoch 28/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8399 - accuracy: 0.7053 - val_loss: 0.8132 - val_accuracy: 0.7118
# Epoch 29/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8369 - accuracy: 0.7054 - val_loss: 0.8461 - val_accuracy: 0.7074
# Epoch 30/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8235 - accuracy: 0.7118 - val_loss: 0.8073 - val_accuracy: 0.7170
# Epoch 31/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8090 - accuracy: 0.7156 - val_loss: 0.8349 - val_accuracy: 0.7088
# Epoch 32/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8097 - accuracy: 0.7171 - val_loss: 0.7961 - val_accuracy: 0.7199
# Epoch 33/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.8004 - accuracy: 0.7200 - val_loss: 0.8543 - val_accuracy: 0.7003
# Epoch 34/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7864 - accuracy: 0.7231 - val_loss: 0.8000 - val_accuracy: 0.7184
# Epoch 35/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7843 - accuracy: 0.7253 - val_loss: 0.8169 - val_accuracy: 0.7095
# Epoch 36/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7763 - accuracy: 0.7298 - val_loss: 0.7771 - val_accuracy: 0.7242
# Epoch 37/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7789 - accuracy: 0.7276 - val_loss: 0.8042 - val_accuracy: 0.7188
# Epoch 38/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7612 - accuracy: 0.7340 - val_loss: 0.7920 - val_accuracy: 0.7279
# Epoch 39/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7553 - accuracy: 0.7369 - val_loss: 0.7337 - val_accuracy: 0.7406
# Epoch 40/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7535 - accuracy: 0.7380 - val_loss: 0.7018 - val_accuracy: 0.7531
# Epoch 41/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7407 - accuracy: 0.7413 - val_loss: 0.6787 - val_accuracy: 0.7622
# Epoch 42/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7370 - accuracy: 0.7445 - val_loss: 0.7430 - val_accuracy: 0.7399
# Epoch 43/200
# 781/781 [==============================] - 15s 20ms/step - loss: 0.7279 - accuracy: 0.7468 - val_loss: 0.6874 - val_accuracy: 0.7599
# Epoch 44/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7235 - accuracy: 0.7509 - val_loss: 0.7350 - val_accuracy: 0.7439
# Epoch 45/200
# 781/781 [==============================] - 15s 20ms/step - loss: 0.7148 - accuracy: 0.7529 - val_loss: 0.7302 - val_accuracy: 0.7493
# Epoch 46/200
# 781/781 [==============================] - 16s 20ms/step - loss: 0.7156 - accuracy: 0.7522 - val_loss: 0.7064 - val_accuracy: 0.7502
# Epoch 47/200
# 781/781 [==============================] - 15s 20ms/step - loss: 0.7176 - accuracy: 0.7500 - val_loss: 0.6917 - val_accuracy: 0.7575
# Epoch 48/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7060 - accuracy: 0.7513 - val_loss: 0.6462 - val_accuracy: 0.7718
# Epoch 49/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.7060 - accuracy: 0.7568 - val_loss: 0.6555 - val_accuracy: 0.7722
# Epoch 50/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6904 - accuracy: 0.7599 - val_loss: 0.6650 - val_accuracy: 0.7676
# Epoch 51/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6981 - accuracy: 0.7572 - val_loss: 0.6191 - val_accuracy: 0.7812
# Epoch 52/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6848 - accuracy: 0.7646 - val_loss: 0.6486 - val_accuracy: 0.7768
# Epoch 53/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6748 - accuracy: 0.7669 - val_loss: 0.6471 - val_accuracy: 0.7727
# Epoch 54/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6874 - accuracy: 0.7613 - val_loss: 0.6623 - val_accuracy: 0.7722
# Epoch 55/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6623 - accuracy: 0.7724 - val_loss: 0.6605 - val_accuracy: 0.7720
# Epoch 56/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6742 - accuracy: 0.7681 - val_loss: 0.6602 - val_accuracy: 0.7739
# Epoch 57/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6588 - accuracy: 0.7717 - val_loss: 0.6302 - val_accuracy: 0.7788
# Epoch 58/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6606 - accuracy: 0.7714 - val_loss: 0.6595 - val_accuracy: 0.7728
# Epoch 59/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6452 - accuracy: 0.7787 - val_loss: 0.6145 - val_accuracy: 0.7887
# Epoch 60/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6538 - accuracy: 0.7735 - val_loss: 0.6438 - val_accuracy: 0.7752
# Epoch 61/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6521 - accuracy: 0.7754 - val_loss: 0.6399 - val_accuracy: 0.7750
# Epoch 62/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6397 - accuracy: 0.7788 - val_loss: 0.6524 - val_accuracy: 0.7771
# Epoch 63/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6316 - accuracy: 0.7812 - val_loss: 0.6068 - val_accuracy: 0.7890
# Epoch 64/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6345 - accuracy: 0.7795 - val_loss: 0.6113 - val_accuracy: 0.7847
# Epoch 65/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6317 - accuracy: 0.7838 - val_loss: 0.6191 - val_accuracy: 0.7863
# Epoch 66/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6218 - accuracy: 0.7871 - val_loss: 0.6084 - val_accuracy: 0.7899
# Epoch 67/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6232 - accuracy: 0.7867 - val_loss: 0.6095 - val_accuracy: 0.7900
# Epoch 68/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6188 - accuracy: 0.7863 - val_loss: 0.5672 - val_accuracy: 0.8049
# Epoch 69/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6168 - accuracy: 0.7890 - val_loss: 0.5952 - val_accuracy: 0.7937
# Epoch 70/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6196 - accuracy: 0.7871 - val_loss: 0.5880 - val_accuracy: 0.8004
# Epoch 71/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6121 - accuracy: 0.7883 - val_loss: 0.5854 - val_accuracy: 0.7978
# Epoch 72/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.6106 - accuracy: 0.7906 - val_loss: 0.5508 - val_accuracy: 0.8097
# Epoch 73/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5985 - accuracy: 0.7975 - val_loss: 0.5811 - val_accuracy: 0.7991
# Epoch 74/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5978 - accuracy: 0.7932 - val_loss: 0.5634 - val_accuracy: 0.8078
# Epoch 75/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5933 - accuracy: 0.7951 - val_loss: 0.5689 - val_accuracy: 0.8036
# Epoch 76/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5888 - accuracy: 0.7975 - val_loss: 0.5528 - val_accuracy: 0.8087
# Epoch 77/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5880 - accuracy: 0.7965 - val_loss: 0.5730 - val_accuracy: 0.8019
# Epoch 78/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5901 - accuracy: 0.8010 - val_loss: 0.5355 - val_accuracy: 0.8132
# Epoch 79/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5846 - accuracy: 0.7987 - val_loss: 0.5735 - val_accuracy: 0.8064
# Epoch 80/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5870 - accuracy: 0.7999 - val_loss: 0.5386 - val_accuracy: 0.8126
# Epoch 81/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5760 - accuracy: 0.8028 - val_loss: 0.5571 - val_accuracy: 0.8074
# Epoch 82/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5768 - accuracy: 0.8018 - val_loss: 0.5576 - val_accuracy: 0.8121
# Epoch 83/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5740 - accuracy: 0.8017 - val_loss: 0.5315 - val_accuracy: 0.8158
# Epoch 84/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5684 - accuracy: 0.8051 - val_loss: 0.5320 - val_accuracy: 0.8187
# Epoch 85/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5636 - accuracy: 0.8065 - val_loss: 0.5573 - val_accuracy: 0.8058
# Epoch 86/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5653 - accuracy: 0.8047 - val_loss: 0.5525 - val_accuracy: 0.8104
# Epoch 87/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5518 - accuracy: 0.8084 - val_loss: 0.5370 - val_accuracy: 0.8169
# Epoch 88/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5564 - accuracy: 0.8113 - val_loss: 0.5139 - val_accuracy: 0.8231
# Epoch 89/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5635 - accuracy: 0.8081 - val_loss: 0.5630 - val_accuracy: 0.8096
# Epoch 90/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5630 - accuracy: 0.8061 - val_loss: 0.5377 - val_accuracy: 0.8190
# Epoch 91/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5427 - accuracy: 0.8133 - val_loss: 0.5222 - val_accuracy: 0.8186
# Epoch 92/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5472 - accuracy: 0.8131 - val_loss: 0.5026 - val_accuracy: 0.8295
# Epoch 93/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5370 - accuracy: 0.8162 - val_loss: 0.5276 - val_accuracy: 0.8213
# Epoch 94/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5491 - accuracy: 0.8103 - val_loss: 0.5308 - val_accuracy: 0.8222
# Epoch 95/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5462 - accuracy: 0.8118 - val_loss: 0.5533 - val_accuracy: 0.8111
# Epoch 96/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5447 - accuracy: 0.8122 - val_loss: 0.5271 - val_accuracy: 0.8160
# Epoch 97/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5450 - accuracy: 0.8130 - val_loss: 0.4907 - val_accuracy: 0.8322
# Epoch 98/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5292 - accuracy: 0.8173 - val_loss: 0.5102 - val_accuracy: 0.8270
# Epoch 99/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5328 - accuracy: 0.8157 - val_loss: 0.5049 - val_accuracy: 0.8262
# Epoch 100/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5313 - accuracy: 0.8164 - val_loss: 0.5047 - val_accuracy: 0.8293
# Epoch 101/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5242 - accuracy: 0.8225 - val_loss: 0.5074 - val_accuracy: 0.8282
# Epoch 102/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5178 - accuracy: 0.8249 - val_loss: 0.4874 - val_accuracy: 0.8336
# Epoch 103/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5267 - accuracy: 0.8190 - val_loss: 0.5190 - val_accuracy: 0.8221
# Epoch 104/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5146 - accuracy: 0.8248 - val_loss: 0.4773 - val_accuracy: 0.8379
# Epoch 105/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5163 - accuracy: 0.8253 - val_loss: 0.5251 - val_accuracy: 0.8238
# Epoch 106/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5164 - accuracy: 0.8226 - val_loss: 0.5057 - val_accuracy: 0.8266
# Epoch 107/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5176 - accuracy: 0.8217 - val_loss: 0.4831 - val_accuracy: 0.8366
# Epoch 108/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5099 - accuracy: 0.8237 - val_loss: 0.4963 - val_accuracy: 0.8295
# Epoch 109/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5127 - accuracy: 0.8278 - val_loss: 0.5473 - val_accuracy: 0.8164
# Epoch 110/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5105 - accuracy: 0.8255 - val_loss: 0.5261 - val_accuracy: 0.8254
# Epoch 111/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4979 - accuracy: 0.8291 - val_loss: 0.4670 - val_accuracy: 0.8408
# Epoch 112/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5067 - accuracy: 0.8268 - val_loss: 0.4576 - val_accuracy: 0.8446
# Epoch 113/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5007 - accuracy: 0.8258 - val_loss: 0.4882 - val_accuracy: 0.8344
# Epoch 114/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5024 - accuracy: 0.8266 - val_loss: 0.4850 - val_accuracy: 0.8355
# Epoch 115/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.5095 - accuracy: 0.8243 - val_loss: 0.4637 - val_accuracy: 0.8400
# Epoch 116/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4961 - accuracy: 0.8324 - val_loss: 0.4906 - val_accuracy: 0.8358
# Epoch 117/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4910 - accuracy: 0.8313 - val_loss: 0.4543 - val_accuracy: 0.8455
# Epoch 118/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4984 - accuracy: 0.8284 - val_loss: 0.4696 - val_accuracy: 0.8377
# Epoch 119/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4918 - accuracy: 0.8311 - val_loss: 0.4607 - val_accuracy: 0.8415
# Epoch 120/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4916 - accuracy: 0.8325 - val_loss: 0.5194 - val_accuracy: 0.8240
# Epoch 121/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4934 - accuracy: 0.8317 - val_loss: 0.5126 - val_accuracy: 0.8274
# Epoch 122/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4874 - accuracy: 0.8340 - val_loss: 0.4912 - val_accuracy: 0.8319
# Epoch 123/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4825 - accuracy: 0.8359 - val_loss: 0.4655 - val_accuracy: 0.8434
# Epoch 124/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4838 - accuracy: 0.8344 - val_loss: 0.4671 - val_accuracy: 0.8444
# Epoch 125/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4826 - accuracy: 0.8330 - val_loss: 0.4494 - val_accuracy: 0.8487
# Epoch 126/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4838 - accuracy: 0.8369 - val_loss: 0.4582 - val_accuracy: 0.8470
# Epoch 127/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4842 - accuracy: 0.8337 - val_loss: 0.5080 - val_accuracy: 0.8286
# Epoch 128/200
# 781/781 [==============================] - 14s 19ms/step - loss: 0.4762 - accuracy: 0.8383 - val_loss: 0.4656 - val_accuracy: 0.8455
# Epoch 129/200
# 781/781 [==============================] - 15s 20ms/step - loss: 0.4801 - accuracy: 0.8348 - val_loss: 0.4531 - val_accuracy: 0.8463
# Epoch 130/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4795 - accuracy: 0.8360 - val_loss: 0.5136 - val_accuracy: 0.8286
# Epoch 131/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4713 - accuracy: 0.8391 - val_loss: 0.4544 - val_accuracy: 0.8481
# Epoch 132/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4806 - accuracy: 0.8360 - val_loss: 0.4775 - val_accuracy: 0.8364
# Epoch 133/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4752 - accuracy: 0.8379 - val_loss: 0.4593 - val_accuracy: 0.8439
# Epoch 134/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4694 - accuracy: 0.8373 - val_loss: 0.5267 - val_accuracy: 0.8223
# Epoch 135/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4564 - accuracy: 0.8408 - val_loss: 0.4983 - val_accuracy: 0.8358
# Epoch 136/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4689 - accuracy: 0.8409 - val_loss: 0.4694 - val_accuracy: 0.8410
# Epoch 137/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4681 - accuracy: 0.8417 - val_loss: 0.4466 - val_accuracy: 0.8478
# Epoch 138/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4610 - accuracy: 0.8432 - val_loss: 0.4708 - val_accuracy: 0.8423
# Epoch 139/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4685 - accuracy: 0.8413 - val_loss: 0.4520 - val_accuracy: 0.8486
# Epoch 140/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4632 - accuracy: 0.8420 - val_loss: 0.4279 - val_accuracy: 0.8576
# Epoch 141/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4609 - accuracy: 0.8428 - val_loss: 0.4756 - val_accuracy: 0.8420
# Epoch 142/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4575 - accuracy: 0.8439 - val_loss: 0.4285 - val_accuracy: 0.8553
# Epoch 143/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4678 - accuracy: 0.8381 - val_loss: 0.4381 - val_accuracy: 0.8507
# Epoch 144/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4497 - accuracy: 0.8452 - val_loss: 0.4723 - val_accuracy: 0.8414
# Epoch 145/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4460 - accuracy: 0.8518 - val_loss: 0.4625 - val_accuracy: 0.8442
# Epoch 146/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4529 - accuracy: 0.8443 - val_loss: 0.4546 - val_accuracy: 0.8486
# Epoch 147/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4503 - accuracy: 0.8480 - val_loss: 0.4767 - val_accuracy: 0.8404
# Epoch 148/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4525 - accuracy: 0.8457 - val_loss: 0.4353 - val_accuracy: 0.8548
# Epoch 149/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4426 - accuracy: 0.8480 - val_loss: 0.4806 - val_accuracy: 0.8419
# Epoch 150/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4519 - accuracy: 0.8469 - val_loss: 0.4534 - val_accuracy: 0.8508
# Epoch 151/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4403 - accuracy: 0.8494 - val_loss: 0.4528 - val_accuracy: 0.8483
# Epoch 152/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4424 - accuracy: 0.8487 - val_loss: 0.4513 - val_accuracy: 0.8490
# Epoch 153/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4388 - accuracy: 0.8477 - val_loss: 0.4376 - val_accuracy: 0.8527
# Epoch 154/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4497 - accuracy: 0.8479 - val_loss: 0.4481 - val_accuracy: 0.8541
# Epoch 155/200
# 781/781 [==============================] - 15s 20ms/step - loss: 0.4383 - accuracy: 0.8497 - val_loss: 0.4096 - val_accuracy: 0.8624
# Epoch 156/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4476 - accuracy: 0.8465 - val_loss: 0.4324 - val_accuracy: 0.8543
# Epoch 157/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4346 - accuracy: 0.8482 - val_loss: 0.4372 - val_accuracy: 0.8546
# Epoch 158/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4357 - accuracy: 0.8500 - val_loss: 0.4264 - val_accuracy: 0.8574
# Epoch 159/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4356 - accuracy: 0.8509 - val_loss: 0.4119 - val_accuracy: 0.8626
# Epoch 160/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4346 - accuracy: 0.8532 - val_loss: 0.4222 - val_accuracy: 0.8632
# Epoch 161/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4302 - accuracy: 0.8520 - val_loss: 0.4055 - val_accuracy: 0.8680
# Epoch 162/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4339 - accuracy: 0.8507 - val_loss: 0.4215 - val_accuracy: 0.8611
# Epoch 163/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4276 - accuracy: 0.8533 - val_loss: 0.4368 - val_accuracy: 0.8543
# Epoch 164/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4382 - accuracy: 0.8521 - val_loss: 0.4214 - val_accuracy: 0.8593
# Epoch 165/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4245 - accuracy: 0.8566 - val_loss: 0.4115 - val_accuracy: 0.8625
# Epoch 166/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4257 - accuracy: 0.8522 - val_loss: 0.4439 - val_accuracy: 0.8498
# Epoch 167/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4279 - accuracy: 0.8552 - val_loss: 0.4242 - val_accuracy: 0.8570
# Epoch 168/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4206 - accuracy: 0.8572 - val_loss: 0.4279 - val_accuracy: 0.8584
# Epoch 169/200
# 781/781 [==============================] - 14s 19ms/step - loss: 0.4258 - accuracy: 0.8551 - val_loss: 0.3966 - val_accuracy: 0.8686
# Epoch 170/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4265 - accuracy: 0.8517 - val_loss: 0.4280 - val_accuracy: 0.8577
# Epoch 171/200
# 781/781 [==============================] - 14s 19ms/step - loss: 0.4231 - accuracy: 0.8533 - val_loss: 0.4607 - val_accuracy: 0.8464
# Epoch 172/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4301 - accuracy: 0.8541 - val_loss: 0.4326 - val_accuracy: 0.8555
# Epoch 173/200
# 781/781 [==============================] - 14s 19ms/step - loss: 0.4108 - accuracy: 0.8602 - val_loss: 0.4594 - val_accuracy: 0.8501
# Epoch 174/200
# 781/781 [==============================] - 14s 18ms/step - loss: 0.4221 - accuracy: 0.8547 - val_loss: 0.4393 - val_accuracy: 0.8568
# Epoch 175/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4177 - accuracy: 0.8554 - val_loss: 0.4090 - val_accuracy: 0.8643
# Epoch 176/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4185 - accuracy: 0.8578 - val_loss: 0.4085 - val_accuracy: 0.8653
# Epoch 177/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4203 - accuracy: 0.8563 - val_loss: 0.3940 - val_accuracy: 0.8686
# Epoch 178/200
# 781/781 [==============================] - 14s 19ms/step - loss: 0.4215 - accuracy: 0.8567 - val_loss: 0.4281 - val_accuracy: 0.8625
# Epoch 179/200
# 781/781 [==============================] - 14s 18ms/step - loss: 0.4127 - accuracy: 0.8610 - val_loss: 0.3984 - val_accuracy: 0.8700
# Epoch 180/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4046 - accuracy: 0.8602 - val_loss: 0.4075 - val_accuracy: 0.8663
# Epoch 181/200
# 781/781 [==============================] - 14s 19ms/step - loss: 0.4098 - accuracy: 0.8594 - val_loss: 0.4122 - val_accuracy: 0.8632
# Epoch 182/200
# 781/781 [==============================] - 14s 19ms/step - loss: 0.4109 - accuracy: 0.8592 - val_loss: 0.4536 - val_accuracy: 0.8559
# Epoch 183/200
# 781/781 [==============================] - 14s 19ms/step - loss: 0.4144 - accuracy: 0.8590 - val_loss: 0.4029 - val_accuracy: 0.8651
# Epoch 184/200
# 781/781 [==============================] - 14s 19ms/step - loss: 0.4163 - accuracy: 0.8572 - val_loss: 0.4024 - val_accuracy: 0.8664
# Epoch 185/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4067 - accuracy: 0.8598 - val_loss: 0.4026 - val_accuracy: 0.8664
# Epoch 186/200
# 781/781 [==============================] - 14s 19ms/step - loss: 0.4047 - accuracy: 0.8611 - val_loss: 0.4023 - val_accuracy: 0.8662
# Epoch 187/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4081 - accuracy: 0.8597 - val_loss: 0.4206 - val_accuracy: 0.8617
# Epoch 188/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4019 - accuracy: 0.8607 - val_loss: 0.4133 - val_accuracy: 0.8630
# Epoch 189/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.3950 - accuracy: 0.8644 - val_loss: 0.4551 - val_accuracy: 0.8531
# Epoch 190/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4017 - accuracy: 0.8632 - val_loss: 0.4091 - val_accuracy: 0.8665
# Epoch 191/200
# 781/781 [==============================] - 14s 19ms/step - loss: 0.4020 - accuracy: 0.8640 - val_loss: 0.4313 - val_accuracy: 0.8596
# Epoch 192/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4030 - accuracy: 0.8623 - val_loss: 0.3932 - val_accuracy: 0.8708
# Epoch 193/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4053 - accuracy: 0.8621 - val_loss: 0.4070 - val_accuracy: 0.8650
# Epoch 194/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4009 - accuracy: 0.8632 - val_loss: 0.4076 - val_accuracy: 0.8674
# Epoch 195/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4056 - accuracy: 0.8606 - val_loss: 0.4043 - val_accuracy: 0.8683
# Epoch 196/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4000 - accuracy: 0.8621 - val_loss: 0.3913 - val_accuracy: 0.8701
# Epoch 197/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4007 - accuracy: 0.8615 - val_loss: 0.4056 - val_accuracy: 0.8669
# Epoch 198/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.3962 - accuracy: 0.8668 - val_loss: 0.3985 - val_accuracy: 0.8649
# Epoch 199/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.4019 - accuracy: 0.8630 - val_loss: 0.4029 - val_accuracy: 0.8655
# Epoch 200/200
# 781/781 [==============================] - 15s 19ms/step - loss: 0.3945 - accuracy: 0.8651 - val_loss: 0.4276 - val_accuracy: 0.8585

# %%
''' plot the history with figsize=(10,5)
    the plot should display the grid and the whole range of values for loss and accuracy
    the plot should have axis labels and legend location should be lower right '''

...

# %% [markdown]
# > The history plot not only indicates that there is no overfitting observed in 200 epochs due to the usage of regularization techniques, but also shows that we could possibly achieve higher accuracies if we trained the model longer.

# %% [markdown]
# > **Test Accuracy Requirement**: For your `final_model`, the minimum required test accuracy on the test images of CIFAR-10 is 0.80. Anything below 0.80 will get zero for Part-III. 0.80+ accuracies are graded accordingly. See "Grading" section for further information on how A5 is graded.

# %%
# Evaluate your final_model on X_test and y_test
final_test_loss, final_test_acc = ...
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4276 - accuracy: 0.8585

# %%
round(final_test_acc, 2)
# Out:
# 0.86

# %% [markdown]
# ## Methods [REQUIRED!]
#
# Write a COMPLETE description of all the methods you have used in your CNN final model here in at least TWO paragraphs. Each paragraph should have at least FOUR lines. Otherwise you get zero for Part-III.
#
# Do NOT include the explanation for Conv2D or MaxPooling2D, as those are the basis of CNN; rather you should include all other methods that you have used such as regularization, data augmentation, etc.
#
# Write your methods HERE:

# %% [markdown]
# ## Conclusions [REQUIRED!]
#
# Write a COMPLETE analysis and conclusion of your experiments and results here in at least one paragraph with four lines. Otherwise your Part-III receives NO credit!
#
# Write your conclusions HERE:

# %% [markdown]
# ## References [REQUIRED!]
#
# Include all the references to codes, websites, articles, notebooks, GitHub repos, etc. that you've used to build your model here. No specific format for references is required, but at the minimum, you should have a separate numbered row for each reference, and include the URL if it has a web link.
#
# If you borrow any code, you must document and comment each line of the code LINE BY LINE to explain exactly what it's doing. In the cell that contains the borrowed code, you should include (as comment) the reference number listed here.
#
# **Warning**: If you borrow a code without proper citation here, it will be flagged and reported as plaigiarism, and the minimum consequence is ZERO in A5.
#
# Enter your references HERE:
#
# [1]      <br>
# [2]      <br>
# ...

# %% [markdown]
# ## Grading
#
# Assignment-5 has a maximum grade of 100. Grading is based on the evaluation of your model on test images of CIFAR-10 dataset (test accuracy). There is NO late period for A5, thus late submissions will NOT be graded and will get ZERO.
#
# The breakdown of the 100 points is as follows:
#
# - Part-I `baseline_model`: [total 20 points]
#     - **Test Accuracy Requirement:** The `baseline_model` must achieve at least 0.70 test accuracy on CIFAR-10 test images.
#
#
# - Part-II `transfer_model`: [total 40 points]
#     - **Test Accuracy Requirement:** The `transfer_model` must achieve at least 0.65 test accuracy on CIFAR-10 test images.
#
#
# - Part-III `final_model`: [total 40 points] You must include Methods, Conclusions and References as required.
#    * **Test Accuracy Requirement:** Test accuracy of the final model < 0.80 --> Part-III grade: zero
#    * (0.80 <= Test accuracy < 0.85) --> 30 points
#    * (0.85 <= Test accuracy) --> 40 points
#
# <b>Very Important Note: </b>
# - You must train all models and generate all history plots. Use "Save and Checkpoint" at the top menu of the Jupyter Notebook to save the outputs.
# - Additionally, you must include at least TWO paragraphs, each with FOUR lines for **Methods** and at least one paragraph with FOUR lines for **Conclusions**. Otherwise, your Part-III will NOT be graded and gets ZERO credit!
#
# **Warning**: If you borrow a code without proper citation as described in **References**, it will be reported as plaigiarism, and the minimum consequence is ZERO in A5.
#
# Follow the instructions of each section carefully. Up to 10 points may be deducted if your submitted notebook is not easy to read and follow or if it has grammatical, spelling or formatting issues.

# %% [markdown]
# Name your notebook ```Lastname-A5.ipynb```. Submit the completed notebook using the ```Assignment-5``` link on Blackboard.
#
# Grading will be based on
#
#   * correct implementation and results,
#   * getting minimum required accuracy on the test images of CIFAR-10 (the accuracy of your CNN on test images), and
#   * readability of the notebook.
#
# <font color=red><b>Due Date: Wednesday May 12th, 11:59PM.</b></font>
